# %%
from app.pipelines.collect import load_stats, load_barometer_jt

stats = load_stats()
jt = load_barometer_jt()

stats.shape
jt.shape
# Out:
# (268424, 6)

# %%
from app.pipelines.clean import clean_stats, clean_barometer_jt

stats_clean = clean_stats(stats)
jt_clean = clean_barometer_jt(jt)

stats_clean.shape, jt_clean.shape
# Out:
# ((441979, 12), (268424, 5))
